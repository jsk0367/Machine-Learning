# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-99b5b5d7-955a-46f8-a4e4-0cc3f9e5060f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-99b5b5d7-955a-46f8-a4e4-0cc3f9e5060f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving images.jpg to images.jpg

# %%
import cv2
import matplotlib.pyplot as plt

img_basic = cv2.imread('images.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()

img_basic = cv2.cvtColor(img_basic, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_GRAY2RGB))
plt.show()

# %% [markdown]
# 이미지 연산

# %%
image = cv2.imread('images.jpg')

print(image.shape)
print(image.size)

# 이미지 Numpy 객체의 특정 픽셀을 가리킵니다.
px = image[100, 100]

# B, G, R 순서로 출력됩니다.
# (단, Gray Scale인 경우에는 B, G, R로 구분되지 않습니다.)
print(px)

# R 값만 출력하기
print(px[2])
# Out:
# (177, 284, 3)
# 150804
# [190 187 183]
# 183

# %% [markdown]
# OpenCV를 활용한 특정 범위 픽셀 변경

# %%
import time

start_time = time.time()
for i in range(0, 100):
    for j in range(0, 100):
        image[i, j] = [255, 255, 255]
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
image[0:100, 0:100] = [0, 0, 0]
print("--- %s seconds ---" % (time.time() - start_time))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# --- 0.019613027572631836 seconds ---
# --- 0.0002872943878173828 seconds ---

# %% [markdown]
# OpenCV를 활용한 ROI(Region of Interest: 관심 있는 영역) 추출

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('images.jpg')

# Numpy Slicing: ROI 처리 가능
roi = image[200:350, 50:200]

# ROI 단위로 이미지 복사하기
image[0:100, 0:100] = roi

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a4fe650013aa> in <module>()
#       8
#       9 # ROI 단위로 이미지 복사하기
# ---> 10 image[0:100, 0:100] = roi
#      11
#      12 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
#
# ValueError: could not broadcast input array from shape (0,150,3) into shape (100,100,3)

# %% [markdown]
# OpenCV를 활용한 픽셀별 색상 다루기

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('images.jpg')
image[:, :, 2] = 0

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
