# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
seed = 0
np.random.seed(seed)
tf.random.set_seed(3)

# %%
# df = df_pre.sample(frac=1)
df_pre = pd.read_csv('data/wine.csv')
df = df_pre.sample(frac=1)  # 전체 데이터에서 샘플을 가져온다. 1= 100%, 0.7 = 70%

# %%
print(df.head())
# Out:
#       7.4   0.7     0   1.9  0.076    11     34   0.9978  3.51  0.56   9.4  5  \
# 5315  6.3  0.18  0.24   3.4  0.053  20.0  119.0  0.99373  3.11  0.52   9.2  6
# 2423  7.0  0.21  0.37   7.2  0.042  36.0  167.0  0.99580  3.26  0.56   9.8  6
# 3517  7.3  0.22  0.50  13.7  0.049  56.0  189.0  0.99940  3.24  0.66   9.0  6
# 1622  6.6  0.27  0.41   1.3  0.052  16.0  142.0  0.99510  3.42  0.47  10.0  6
# 4060  8.3  0.25  0.33   2.5  0.053  12.0   72.0  0.99404  2.89  0.48   9.5  5
#
#       1
# 5315  0
# 2423  0
# 3517  0
# 1622  0
# 4060  0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6496 entries, 5315 to 2732
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   7.4     6496 non-null   float64
#  1   0.7     6496 non-null   float64
#  2   0       6496 non-null   float64
#  3   1.9     6496 non-null   float64
#  4   0.076   6496 non-null   float64
#  5   11      6496 non-null   float64
#  6   34      6496 non-null   float64
#  7   0.9978  6496 non-null   float64
#  8   3.51    6496 non-null   float64
#  9   0.56    6496 non-null   float64
#  10  9.4     6496 non-null   float64
#  11  5       6496 non-null   int64
#  12  1       6496 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 710.5 KB
# None

# %%
# 1: red wine, 0: white wine
# 1과 0을 구분하는 회귀, 바이너리 연산

# %%
dataset = df.values
print(dataset.dtype)
# 전체가 float 이므로 형변환 불필요
# Out:
# float64

# %%
X = dataset[:, :12]
Y = dataset[:, 12]

# %%
model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                390
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 104
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 손실 함수 및 optimize 연걸
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
import os

MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR) :  # 같은 파일명이 존재하는지 확인
    os.mkdir(MODEL_DIR)   # 모델 생성
    

modelpath = './model/{epoch:02d}-{val_loss:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True) # 체크포인트 생성, 무엇을 체크할 것인지 지정(mointor)

# monitor=val_loss : 무엇을 체크할 것인지 지정. val_loss 를 관찰하라는 뜻
# verbose=1 : 중간 과정을 계속 출력하라
# save_best_only=True : 모델이 향상될 때만 저장하라

# %%
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])

# validation_split=0.2 : 20% 를 뗴어놓고, 80%만 훈련시킨 후, 나머지 20% 를 validate을 해주고, 그때마다 그 값을 나타내 보여달라
# verbose=0 : 출력 값을 보이지 마라
# print("Accuracy:  %.4f" % (model.evaluate(X, Y)))
# Out:
# Epoch 00001: val_loss improved from inf to 0.37545, saving model to ./model\01-0.3755.hdf5
#
# Epoch 00002: val_loss improved from 0.37545 to 0.27675, saving model to ./model\02-0.2767.hdf5
#
# Epoch 00003: val_loss improved from 0.27675 to 0.23765, saving model to ./model\03-0.2376.hdf5
#
# Epoch 00004: val_loss improved from 0.23765 to 0.22889, saving model to ./model\04-0.2289.hdf5
#
# Epoch 00005: val_loss improved from 0.22889 to 0.22238, saving model to ./model\05-0.2224.hdf5
#
# Epoch 00006: val_loss improved from 0.22238 to 0.21502, saving model to ./model\06-0.2150.hdf5
#
# Epoch 00007: val_loss improved from 0.21502 to 0.21395, saving model to ./model\07-0.2140.hdf5
#
# Epoch 00008: val_loss improved from 0.21395 to 0.20424, saving model to ./model\08-0.2042.hdf5
#
# Epoch 00009: val_loss improved from 0.20424 to 0.19721, saving model to ./model\09-0.1972.hdf5
#
# Epoch 00010: val_loss improved from 0.19721 to 0.19328, saving model to ./model\10-0.1933.hdf5
#
# Epoch 00011: val_loss improved from 0.19328 to 0.18812, saving model to ./model\11-0.1881.hdf5
#
# Epoch 00012: val_loss did not improve from 0.18812
#
# Epoch 00013: val_loss improved from 0.18812 to 0.18759, saving model to ./model\13-0.1876.hdf5
#
# Epoch 00014: val_loss improved from 0.18759 to 0.17851, saving model to ./model\14-0.1785.hdf5
#
# Epoch 00015: val_loss improved from 0.17851 to 0.17389, saving model to ./model\15-0.1739.hdf5
#
# Epoch 00016: val_loss improved from 0.17389 to 0.17340, saving model to ./model\16-0.1734.hdf5
#
# Epoch 00017: val_loss improved from 0.17340 to 0.16767, saving model to ./model\17-0.1677.hdf5
#
# Epoch 00018: val_loss did not improve from 0.16767
#
# Epoch 00019: val_loss improved from 0.16767 to 0.16127, saving model to ./model\19-0.1613.hdf5
#
# Epoch 00020: val_loss improved from 0.16127 to 0.16027, saving model to ./model\20-0.1603.hdf5
#
# Epoch 00021: val_loss improved from 0.16027 to 0.15693, saving model to ./model\21-0.1569.hdf5
#
# Epoch 00022: val_loss improved from 0.15693 to 0.15282, saving model to ./model\22-0.1528.hdf5
#
# Epoch 00023: val_loss improved from 0.15282 to 0.15035, saving model to ./model\23-0.1504.hdf5
#
# Epoch 00024: val_loss did not improve from 0.15035
#
# Epoch 00025: val_loss improved from 0.15035 to 0.14429, saving model to ./model\25-0.1443.hdf5
#
# Epoch 00026: val_loss improved from 0.14429 to 0.14007, saving model to ./model\26-0.1401.hdf5
#
# Epoch 00027: val_loss improved from 0.14007 to 0.13627, saving model to ./model\27-0.1363.hdf5
#
# Epoch 00028: val_loss improved from 0.13627 to 0.13206, saving model to ./model\28-0.1321.hdf5
#
# Epoch 00029: val_loss improved from 0.13206 to 0.13018, saving model to ./model\29-0.1302.hdf5
#
# Epoch 00030: val_loss improved from 0.13018 to 0.12573, saving model to ./model\30-0.1257.hdf5
#
# Epoch 00031: val_loss improved from 0.12573 to 0.12153, saving model to ./model\31-0.1215.hdf5
#
# Epoch 00032: val_loss did not improve from 0.12153
#
# Epoch 00033: val_loss improved from 0.12153 to 0.11654, saving model to ./model\33-0.1165.hdf5
#
# Epoch 00034: val_loss improved from 0.11654 to 0.11208, saving model to ./model\34-0.1121.hdf5
#
# Epoch 00035: val_loss did not improve from 0.11208
#
# Epoch 00036: val_loss did not improve from 0.11208
#
# Epoch 00037: val_loss improved from 0.11208 to 0.10527, saving model to ./model\37-0.1053.hdf5
#
# Epoch 00038: val_loss improved from 0.10527 to 0.10260, saving model to ./model\38-0.1026.hdf5
#
# Epoch 00039: val_loss improved from 0.10260 to 0.10115, saving model to ./model\39-0.1012.hdf5
#
# Epoch 00040: val_loss improved from 0.10115 to 0.09982, saving model to ./model\40-0.0998.hdf5
#
# Epoch 00041: val_loss did not improve from 0.09982
#
# Epoch 00042: val_loss improved from 0.09982 to 0.09903, saving model to ./model\42-0.0990.hdf5
#
# Epoch 00043: val_loss improved from 0.09903 to 0.09873, saving model to ./model\43-0.0987.hdf5
#
# Epoch 00044: val_loss improved from 0.09873 to 0.09272, saving model to ./model\44-0.0927.hdf5
#
# Epoch 00045: val_loss improved from 0.09272 to 0.09095, saving model to ./model\45-0.0909.hdf5
#
# Epoch 00046: val_loss improved from 0.09095 to 0.09008, saving model to ./model\46-0.0901.hdf5
#
# Epoch 00047: val_loss improved from 0.09008 to 0.08853, saving model to ./model\47-0.0885.hdf5
#
# Epoch 00048: val_loss improved from 0.08853 to 0.08797, saving model to ./model\48-0.0880.hdf5
#
# Epoch 00049: val_loss did not improve from 0.08797
#
# Epoch 00050: val_loss improved from 0.08797 to 0.08517, saving model to ./model\50-0.0852.hdf5
#
# Epoch 00051: val_loss did not improve from 0.08517
#
# Epoch 00052: val_loss improved from 0.08517 to 0.08431, saving model to ./model\52-0.0843.hdf5
#
# Epoch 00053: val_loss did not improve from 0.08431
#
# Epoch 00054: val_loss improved from 0.08431 to 0.08134, saving model to ./model\54-0.0813.hdf5
#
# Epoch 00055: val_loss did not improve from 0.08134
#
# Epoch 00056: val_loss improved from 0.08134 to 0.07910, saving model to ./model\56-0.0791.hdf5
#
# Epoch 00057: val_loss did not improve from 0.07910
#
# Epoch 00058: val_loss did not improve from 0.07910
#
# Epoch 00059: val_loss improved from 0.07910 to 0.07738, saving model to ./model\59-0.0774.hdf5
#
# Epoch 00060: val_loss did not improve from 0.07738
#
# Epoch 00061: val_loss improved from 0.07738 to 0.07728, saving model to ./model\61-0.0773.hdf5
#
# Epoch 00062: val_loss improved from 0.07728 to 0.07354, saving model to ./model\62-0.0735.hdf5
#
# Epoch 00063: val_loss did not improve from 0.07354
#
# Epoch 00064: val_loss did not improve from 0.07354
#
# Epoch 00065: val_loss did not improve from 0.07354
#
# Epoch 00066: val_loss did not improve from 0.07354
#
# Epoch 00067: val_loss did not improve from 0.07354
#
# Epoch 00068: val_loss improved from 0.07354 to 0.06982, saving model to ./model\68-0.0698.hdf5
#
# Epoch 00069: val_loss did not improve from 0.06982
#
# Epoch 00070: val_loss improved from 0.06982 to 0.06934, saving model to ./model\70-0.0693.hdf5
#
# Epoch 00071: val_loss did not improve from 0.06934
#
# Epoch 00072: val_loss did not improve from 0.06934
#
# Epoch 00073: val_loss did not improve from 0.06934
#
# Epoch 00074: val_loss did not improve from 0.06934
#
# Epoch 00075: val_loss improved from 0.06934 to 0.06661, saving model to ./model\75-0.0666.hdf5
#
# Epoch 00076: val_loss did not improve from 0.06661
#
# Epoch 00077: val_loss did not improve from 0.06661
#
# Epoch 00078: val_loss improved from 0.06661 to 0.06572, saving model to ./model\78-0.0657.hdf5
#
# Epoch 00079: val_loss did not improve from 0.06572
#
# Epoch 00080: val_loss did not improve from 0.06572
#
# Epoch 00081: val_loss did not improve from 0.06572
#
# Epoch 00082: val_loss did not improve from 0.06572
#
# Epoch 00083: val_loss did not improve from 0.06572
#
# Epoch 00084: val_loss improved from 0.06572 to 0.06383, saving model to ./model\84-0.0638.hdf5
#
# Epoch 00085: val_loss improved from 0.06383 to 0.06339, saving model to ./model\85-0.0634.hdf5
#
# Epoch 00086: val_loss did not improve from 0.06339
#
# Epoch 00087: val_loss improved from 0.06339 to 0.06233, saving model to ./model\87-0.0623.hdf5
#
# Epoch 00088: val_loss did not improve from 0.06233
#
# Epoch 00089: val_loss did not improve from 0.06233
#
# Epoch 00090: val_loss did not improve from 0.06233
#
# Epoch 00091: val_loss improved from 0.06233 to 0.06183, saving model to ./model\91-0.0618.hdf5
#
# Epoch 00092: val_loss did not improve from 0.06183
#
# Epoch 00093: val_loss did not improve from 0.06183
#
# Epoch 00094: val_loss did not improve from 0.06183
#
# Epoch 00095: val_loss improved from 0.06183 to 0.06096, saving model to ./model\95-0.0610.hdf5
#
# Epoch 00096: val_loss did not improve from 0.06096
#
# Epoch 00097: val_loss did not improve from 0.06096
#
# Epoch 00098: val_loss did not improve from 0.06096
#
# Epoch 00099: val_loss did not improve from 0.06096
#
# Epoch 00100: val_loss did not improve from 0.06096
#
# Epoch 00101: val_loss did not improve from 0.06096
#
# Epoch 00102: val_loss did not improve from 0.06096
#
# Epoch 00103: val_loss improved from 0.06096 to 0.05944, saving model to ./model\103-0.0594.hdf5
#
# Epoch 00104: val_loss did not improve from 0.05944
#
# Epoch 00105: val_loss did not improve from 0.05944
#
# Epoch 00106: val_loss did not improve from 0.05944
#
# Epoch 00107: val_loss did not improve from 0.05944
#
# Epoch 00108: val_loss improved from 0.05944 to 0.05911, saving model to ./model\108-0.0591.hdf5
#
# Epoch 00109: val_loss did not improve from 0.05911
#
# Epoch 00110: val_loss improved from 0.05911 to 0.05841, saving model to ./model\110-0.0584.hdf5
#
# Epoch 00111: val_loss did not improve from 0.05841
#
# Epoch 00112: val_loss improved from 0.05841 to 0.05818, saving model to ./model\112-0.0582.hdf5
#
# Epoch 00113: val_loss did not improve from 0.05818
#
# Epoch 00114: val_loss did not improve from 0.05818
#
# Epoch 00115: val_loss did not improve from 0.05818
#
# Epoch 00116: val_loss did not improve from 0.05818
#
# Epoch 00117: val_loss improved from 0.05818 to 0.05748, saving model to ./model\117-0.0575.hdf5
#
# Epoch 00118: val_loss did not improve from 0.05748
#
# Epoch 00119: val_loss did not improve from 0.05748
#
# Epoch 00120: val_loss did not improve from 0.05748
#
# Epoch 00121: val_loss did not improve from 0.05748
#
# Epoch 00122: val_loss did not improve from 0.05748
#
# Epoch 00123: val_loss improved from 0.05748 to 0.05649, saving model to ./model\123-0.0565.hdf5
#
# Epoch 00124: val_loss did not improve from 0.05649
#
# Epoch 00125: val_loss did not improve from 0.05649
#
# Epoch 00126: val_loss improved from 0.05649 to 0.05643, saving model to ./model\126-0.0564.hdf5
#
# Epoch 00127: val_loss did not improve from 0.05643
#
# Epoch 00128: val_loss did not improve from 0.05643
#
# Epoch 00129: val_loss did not improve from 0.05643
#
# Epoch 00130: val_loss did not improve from 0.05643
#
# Epoch 00131: val_loss did not improve from 0.05643
#
# Epoch 00132: val_loss did not improve from 0.05643
#
# Epoch 00133: val_loss did not improve from 0.05643
#
# Epoch 00134: val_loss did not improve from 0.05643
#
# Epoch 00135: val_loss did not improve from 0.05643
#
# Epoch 00136: val_loss improved from 0.05643 to 0.05514, saving model to ./model\136-0.0551.hdf5
#
# Epoch 00137: val_loss did not improve from 0.05514
#
# Epoch 00138: val_loss did not improve from 0.05514
#
# Epoch 00139: val_loss did not improve from 0.05514
#
# Epoch 00140: val_loss did not improve from 0.05514
#
# Epoch 00141: val_loss did not improve from 0.05514
#
# Epoch 00142: val_loss did not improve from 0.05514
#
# Epoch 00143: val_loss did not improve from 0.05514
#
# Epoch 00144: val_loss did not improve from 0.05514
#
# Epoch 00145: val_loss improved from 0.05514 to 0.05494, saving model to ./model\145-0.0549.hdf5
#
# Epoch 00146: val_loss did not improve from 0.05494
#
# Epoch 00147: val_loss did not improve from 0.05494
#
# Epoch 00148: val_loss did not improve from 0.05494
#
# Epoch 00149: val_loss did not improve from 0.05494
#
# Epoch 00150: val_loss improved from 0.05494 to 0.05409, saving model to ./model\150-0.0541.hdf5
#
# Epoch 00151: val_loss did not improve from 0.05409
#
# Epoch 00152: val_loss did not improve from 0.05409
#
# Epoch 00153: val_loss improved from 0.05409 to 0.05399, saving model to ./model\153-0.0540.hdf5
#
# Epoch 00154: val_loss did not improve from 0.05399
#
# Epoch 00155: val_loss did not improve from 0.05399
#
# Epoch 00156: val_loss did not improve from 0.05399
#
# Epoch 00157: val_loss did not improve from 0.05399
#
# Epoch 00158: val_loss did not improve from 0.05399
#
# Epoch 00159: val_loss did not improve from 0.05399
#
# Epoch 00160: val_loss did not improve from 0.05399
#
# Epoch 00161: val_loss did not improve from 0.05399
#
# Epoch 00162: val_loss did not improve from 0.05399
#
# Epoch 00163: val_loss did not improve from 0.05399
#
# Epoch 00164: val_loss did not improve from 0.05399
#
# Epoch 00165: val_loss did not improve from 0.05399
#
# Epoch 00166: val_loss did not improve from 0.05399
#
# Epoch 00167: val_loss did not improve from 0.05399
#
# Epoch 00168: val_loss did not improve from 0.05399
#
# Epoch 00169: val_loss did not improve from 0.05399
#
# Epoch 00170: val_loss did not improve from 0.05399
#
# Epoch 00171: val_loss did not improve from 0.05399
#
# Epoch 00172: val_loss did not improve from 0.05399
#
# Epoch 00173: val_loss did not improve from 0.05399
#
# Epoch 00174: val_loss did not improve from 0.05399
#
# Epoch 00175: val_loss did not improve from 0.05399
#
# Epoch 00176: val_loss did not improve from 0.05399
#
# Epoch 00177: val_loss did not improve from 0.05399
#
# Epoch 00178: val_loss did not improve from 0.05399
#
# Epoch 00179: val_loss did not improve from 0.05399
#
# Epoch 00180: val_loss did not improve from 0.05399
#
# Epoch 00181: val_loss improved from 0.05399 to 0.05271, saving model to ./model\181-0.0527.hdf5
#
# Epoch 00182: val_loss did not improve from 0.05271
#
# Epoch 00183: val_loss did not improve from 0.05271
#
# Epoch 00184: val_loss did not improve from 0.05271
#
# Epoch 00185: val_loss did not improve from 0.05271
#
# Epoch 00186: val_loss did not improve from 0.05271
#
# Epoch 00187: val_loss did not improve from 0.05271
#
# Epoch 00188: val_loss did not improve from 0.05271
#
# Epoch 00189: val_loss did not improve from 0.05271
#
# Epoch 00190: val_loss did not improve from 0.05271
#
# Epoch 00191: val_loss did not improve from 0.05271
#
# Epoch 00192: val_loss did not improve from 0.05271
#
# Epoch 00193: val_loss did not improve from 0.05271
#
# Epoch 00194: val_loss did not improve from 0.05271
#
# Epoch 00195: val_loss did not improve from 0.05271
#
# Epoch 00196: val_loss did not improve from 0.05271
#
# Epoch 00197: val_loss did not improve from 0.05271
#
# Epoch 00198: val_loss did not improve from 0.05271
#
# Epoch 00199: val_loss did not improve from 0.05271
#
# Epoch 00200: val_loss did not improve from 0.05271
